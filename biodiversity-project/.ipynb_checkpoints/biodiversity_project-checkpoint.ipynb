# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import scipy.stats as stats

observations = pd.read_csv('observations_df.csv')
species = pd.read_csv('species_df.csv')

# %%
# Examine datasets

observations.head()
# Out:
#             scientific_name                            park_name  observations
# 0        Vicia benghalensis  Great Smoky Mountains National Park            68
# 1            Neovison vison  Great Smoky Mountains National Park            77
# 2         Prunus subcordata               Yosemite National Park           138
# 3      Abutilon theophrasti                  Bryce National Park            84
# 4  Githopsis specularioides  Great Smoky Mountains National Park            85

# %%
# Examine merged dataset

print('Species Categories:')
print(master.category.value_counts())
print()
print('Conservation Status:')
print(master.conservation_status.value_counts())
# Out:
# Species Categories:
# Vascular Plant       19560
# Bird                  2364
# Nonvascular Plant     1332
# Mammal                1200
# Fish                   524
# Amphibian              328
# Reptile                324
# Name: category, dtype: int64
#
# Conservation Status:
# No Concern            24752
# Species of Concern      732
# Endangered               80
# Threatened               44
# In Recovery              24
# Name: conservation_status, dtype: int64

# %%
# Bar plot to visualize frequency of different conservation statuses

status = list(master.conservation_status.unique())
frequency = []
for s in status:
    frequency.append(len(master[master.conservation_status == s]))
    
print(status)
print(frequency)

# Plot with 'No Concern'
plt.figure(figsize = (10, 4))
plt.bar(status, frequency)
plt.title('Frequency of Conservation Status, Including \'No Concern\'')
plt.xlabel('Conservation Status')
plt.show()

# Plot without 'No Concern'
plt.figure(figsize = (10, 4))
plt.bar(status[1:], frequency[1:])
plt.title('Frequency of Conservation Status')
plt.xlabel('Conservation Status')
plt.show()
# Out:
# ['No Concern', 'Species of Concern', 'Endangered', 'In Recovery', 'Threatened']
# [24752, 732, 80, 24, 44]

# %%
# Endangered

endangered = master[master.conservation_status != 'No Concern']
print(endangered.category.value_counts().sum())
print(endangered.category.value_counts())

print()

endangered_pop = []

population_prop = []
species_names = list(master.category.unique())

for n in species_names:
    endangered_pop.append(len(endangered[endangered.category == n]))

for i in species_names:
    population_prop.append(len(endangered[endangered.category == i]) / 880)

species_prop = list(zip(species_names, population_prop))

for n in species_prop:
    print('{animal}: {proportion}'.format(
        animal = n[0], 
        proportion = n[1]))
# Out:
# 880
# Bird                 348
# Mammal               232
# Vascular Plant       184
# Fish                  48
# Amphibian             28
# Reptile               20
# Nonvascular Plant     20
# Name: category, dtype: int64
#
# Mammal: 0.2636363636363636
# Bird: 0.39545454545454545
# Reptile: 0.022727272727272728
# Amphibian: 0.031818181818181815
# Fish: 0.05454545454545454
# Vascular Plant: 0.20909090909090908
# Nonvascular Plant: 0.022727272727272728

# %%
# Bar plot of endangered species populations

plt.figure(figsize = (14, 4))
plt.bar(species_names, endangered_pop)
plt.title('Endangered Species Populations')
plt.xlabel('Species')
plt.show()

# %%
# Pie chart of endangered species proportions

plt.pie(population_prop, autopct='%0.1f%%')
plt.title('Proportion of Endangered Species')
plt.legend(species_names)
plt.axis('equal')
plt.show()

# %%
# Most spotted species at each park

yosemite = master[master.park_name == 'Yosemite National Park']
smoky = master[master.park_name == 'Great Smoky Mountains National Park']
bryce = master[master.park_name == 'Bryce National Park']
yellowstone = master[master.park_name == 'Yellowstone National Park']

# %%
print('Yosemite:')
print(yosemite.category.value_counts())
print()
print('Great Smoky Mountains:')
print(smoky.category.value_counts())
print()
print('Bryce:')
print(bryce.category.value_counts())
print()
print('Yellowstone:')
print(yellowstone.category.value_counts())
# Out:
# Yosemite:
# Vascular Plant       4890
# Bird                  591
# Nonvascular Plant     333
# Mammal                300
# Fish                  131
# Amphibian              82
# Reptile                81
# Name: category, dtype: int64
#
# Great Smoky Mountains:
# Vascular Plant       4890
# Bird                  591
# Nonvascular Plant     333
# Mammal                300
# Fish                  131
# Amphibian              82
# Reptile                81
# Name: category, dtype: int64
#
# Bryce:
# Vascular Plant       4890
# Bird                  591
# Nonvascular Plant     333
# Mammal                300
# Fish                  131
# Amphibian              82
# Reptile                81
# Name: category, dtype: int64
#
# Yellowstone:
# Vascular Plant       4890
# Bird                  591
# Nonvascular Plant     333
# Mammal                300
# Fish                  131
# Amphibian              82
# Reptile                81
# Name: category, dtype: int64
